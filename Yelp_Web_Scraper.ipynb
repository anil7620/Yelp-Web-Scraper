# %%
import bs4 as bs
import urllib.request as url_x
import pandas as pd

# %%
BusinessNames=[]
Phone=[]
Address=[]
Urls=[]
state_name = input('Enter State name here:')
print('Process Ignited')
# Out:
# Enter State name here:anil
# Process Ignited

# %%
url='https://www.yelp.com/search?cflt=restaurants&find_loc=San+Francisco%2C+CA'

urlsource=''+url+'&start='

# %%
no_of_pages=5
for iteration in range(no_of_pages):
  s=iteration*10
  if(s==0):
    s=1
  source = url_x.urlopen(urlsource+str(s))
  print(urlsource+str(s))

  page_soup = bs.BeautifulSoup(source, 'html.parser')
  mains = page_soup.find_all("div", {"class": " scrollablePhotos__09f24__1PpB8 arrange__09f24__AiSIM border-color--default__09f24__R1nRO"})
  for main in mains:
      try:
          busname = main.find("a", {"class" : " link__09f24__1MGLa link-color--inherit__09f24__3Cplm link-size--inherit__09f24__3Javq"}).text
          BusinessNames.append(busname)
          pnumber = main.find("p", {"class" : " text__09f24__1RhSS text-color--black-extra-light__09f24__2ZRGr text-align--right__09f24__3UXhi text-size--small__09f24__I8np9"}).text
          Phone.append(pnumber)
          address = main.find("span", {"class" : " raw__09f24__3Obuy"}).text
          Address.append(address)
          url = main.find("a", {"class" : " link__09f24__1MGLa link-color--inherit__09f24__3Cplm link-size--inherit__09f24__3Javq"})['href']
          Urls.append("yelp.com" + url)
      except:
          print(None)
  print('Loading......')
print('Done with processing...')
# Out:
# https://www.yelp.com/search?cflt=restaurants&find_loc=San+Francisco%2C+CA&start=1
# Loading......
# https://www.yelp.com/search?cflt=restaurants&find_loc=San+Francisco%2C+CA&start=10
# Loading......
# https://www.yelp.com/search?cflt=restaurants&find_loc=San+Francisco%2C+CA&start=20
# Loading......
# https://www.yelp.com/search?cflt=restaurants&find_loc=San+Francisco%2C+CA&start=30
# Loading......
# https://www.yelp.com/search?cflt=restaurants&find_loc=San+Francisco%2C+CA&start=40
# Loading......
# Done with processing...

# %%
dictionary = {'BusinessNames': BusinessNames, 'Address': Address, 'State': state_name, 'Phone': Phone,  'Urls': Urls} 
df=pd.DataFrame(dict([(k,pd.Series(v)) for k,v in dictionary.items()]))

# %%
df
# Out:
#                      BusinessNames  ...                                               Urls
# 0                Marufuku Ramen SF  ...       yelp.com/biz/marufuku-ramen-sf-san-francisco
# 1                              Ken  ...                     yelp.com/biz/ken-san-francisco
# 2                    Kitchen Story  ...           yelp.com/biz/kitchen-story-san-francisco
# 3   Farmhouse Kitchen Thai Cuisine  ...  yelp.com/biz/farmhouse-kitchen-thai-cuisine-sa...
# 4            Fog Harbor Fish House  ...  yelp.com/biz/fog-harbor-fish-house-san-francis...
# 5                      Sweet Maple  ...             yelp.com/biz/sweet-maple-san-francisco
# 6                        Starbelly  ...               yelp.com/biz/starbelly-san-francisco
# 7                          Beretta  ...                 yelp.com/biz/beretta-san-francisco
# 8                   Beretta Pop Up  ...        yelp.com/biz/beretta-pop-up-san-francisco-2
# 9                        Tastebuds  ...             yelp.com/biz/tastebuds-san-francisco-2
# 10                       Tastebuds  ...             yelp.com/biz/tastebuds-san-francisco-2
# 11                        The Snug  ...                yelp.com/biz/the-snug-san-francisco
